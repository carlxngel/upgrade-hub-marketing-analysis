# %% [markdown]
# INSIGHTS CLAVE
#
# 1.EL CANAL REFERRAL ES EL MÁS EFICIENTE
#
# Tiene el mayor ROI promedio.
#
# Las campañas de tipo Email en Referral destacan con ROIs hasta 0.8.
#
# RECOMENDACIÓN
#
# 📈 Potenciar el canal Referral, especialmente con campañas de bajo coste y alta segmentación como Email Marketing.
#
#
# 2.ALTA CONCENTRACIÓN DE CAMPAÑAS POCO EFECTIVAS
#
# La mayoría de las campañas están en el rango de baja inversión (<0.2€) y baja facturación (<0.2€).
#
# Muchas de ellas no escalan ingresos, lo que indica estrategias de bajo presupuesto ineficientes.
#
# RECOMENDACIÓN
#
# 💰 Reevalúar la estrategia de campañas de bajo presupuesto. Priorizar calidad sobre cantidad y experimenta con presupuestos medios optimizados.
#
# 3.ROI PROMEDIO MODERADO PERO MEJORABLE
#
# ROI medio de 0.54, con pocas campañas superando 0.9.
#
# Algunas campañas con alta inversión no generaron ingresos proporcionales.
#
# RECOMENDACIÓN
#
# 🎯 Establecer un ROI objetivo mínimo de 0.6. Auditar y ajustar campañas que estén por debajo de ese umbral.
#
# 4.FACTURACIÓN Y DURACIÓN NO ESTÁN CORRELACIONADOS
#
# Campañas largas (>500 días) no aseguran mayor facturación.
#
# El rango óptimo parece ser 300-400 días, donde se concentra la mayoría con ingresos moderados.
#
# RECOMENDACIÓN
#
# 🕒 Optimizar la duración de campañas. Evitar extender campañas sin resultados claros más allá de 400 días.
#
# 5.PATRÓN ESTACIONAL CLARO EN EL RENDIMIENTO
#
# ROI, conversión y facturación mejoran en meses 1, 3, 9 y 12.
#
# El mes 7 (julio) es el menos productivo.
#
# RECOMENDACIÓN
#
# 📆 Ajustar el calendario de campañas para intensificar esfuerzos en los meses más rentables y reducir inversión en los menos eficaces.
#
# 6.CAMPAÑAS TIPO EMAIL, WEBINAR Y SOCIAL MEDIA SON LAS MÁS RENTABLES
#
# Email destaca por eficiencia y bajo coste.
#
# Podcast tiene el ROI más bajo y menor estabilidad.
#
# RECOMENDACIÓN
#
# 🛠️ Priorizar tipos de campaña que combinan bajo coste y buenos resultados. Revisar si Podcast justifica su continuidad.
#
# 7.TIPO DE CLIENTE NO AFECTA SIGNIFICATIVAMENTE A LA CONVERSIÓN
#
# Clientes B2B convierten mejor (0.551) que B2C (0.537).
#
# RECOMENDACIÓN
#
# 🔍 Asegurar una buena segmentación del público objetivo. Personalizar campañas según perfil (B2B/B2C) para maximizar conversiones.
