# %% [markdown]
# ONCLUSIONES
#
# 1.Canales más utilizados en las campañas
#
# Promotion es el canal más usado, seguido de referral, organic y paid.
# La diferencia entre los canales principales es pequeña, lo que indica una estrategia multicanal equilibrada.
#
# 2.Relación entre Canal, Inversión y Facturación
#
# Todos los canales presentan una distribución similar de facturación e inversión.
# No hay un canal que destaque claramente por tener campañas con mucha mayor facturación o inversión.
#
# 3.ROI promedio por canal de marketing
# CONCLUSIONES
#
# 1.Concentración de campañas
#
# La mayoría de las campañas se concentran en niveles bajos de inversión (menor a 0.2€) y facturación (menor a 0.2€), con un alto número de campañas (hasta 40) en este rango.
# Hay una dispersión baja, con pocas campañas que alcanzan inversiones o facturaciones más altas.
#
# 2.Relación inversión-ingresos
#
# No hay una correlación clara entre inversión e ingresos. La mayoría de las campañas con baja inversión también generan bajos ingresos.
# Una excepción notable es una campaña con una inversión alta (cerca de 1e7€) pero con ingresos bajos (menor a 0.2€), lo que sugiere un ROI muy bajo para esa campaña.
#
# 3.Eficiencia
#
# Las campañas con baja inversión no logran escalar significativamente los ingresos, lo que indica una posible falta de efectividad en las estrategias de bajo presupuesto.
# La campaña de alta inversión (1e7€) es un outlier y parece ser ineficiente, ya que no generó ingresos proporcionales.
#
# CONCLUSIONES GENERALES
#
# En resumen, la mayoría de las campañas operan con baja inversión y generan ingresos modestos, mientras que una campaña de alta inversión resultó ineficiente. Esto sugiere que las estrategias actuales necesitan ajustes para mejorar la relación inversión-ingresos.
# CONCLUSIONES
#
# 1.ROI
#
# La mayoría de las campañas tienen un ROI entre 0.5 y 0.8, o sea, ganan entre 50 y 80 centimos por cada euro. Pocas superan 0.9.
#
# 2.Facturación
#
# La mayoría está entre 0.6 y 0.8 (millones de euros), lo que significa ingresos decentes, pero no extremos.
#
# 3.Beneficio neto
#
# Los colores claros (amarillo) indican más beneficio (hasta 0.8), y los oscuros (morado) menos o pérdidas (hasta -0.2). Las campañas con ROI alto (más de 0.7) suelen tener más beneficio.
#
# 4.Tasa de conversión
#
# Indica cuánta gente compró o actuó tras ver la campaña. La mayoría de las burbujas son pequeñas (tasas bajas), y las pocas grandes no siempre están en campañas con alto ROI o facturación.
#
# CONCLUSIONES GENERALES
#
# Las campañas que dan más ganancias suelen tener un ROI mayor a 0.7, pero no siempre tienen los mayores ingresos o tasas de conversión.
# CONCLUSIONES
#
# 1.ROI Promedio
# Varía entre 0.48 y 0.58, con picos en los meses 2, 9 y 12 (0.58), y un mínimo en el mes 7 (0.48).
# Hay una tendencia estacional con altibajos, sugiriendo que el rendimiento mejora en ciertos meses (inicio de año, otoño e invierno).
#
# 2.Tasa de Conversión Promedio
#
# Oscila entre 0.50 y 0.62, con picos en los meses 1, 3, 9 y 12 (0.62), y un mínimo en el mes 7 (0.50).
# Sigue un patrón similar al ROI, con mejores tasas al inicio y final del año.
#
# 3.Facturación Promedio
#
# Varía entre 480 y 560 miles de euros, con picos en los meses 1, 3, 9 y 12 (560k€), y un mínimo en el mes 7 (480k€).
# La facturación se alinea con los picos de ROI y tasa de conversión.
#
# CONCLUSIONES GENERALES
#
# El rendimiento de las campañas tiene un patrón estacional, con mejores resultados (ROI, tasa de conversión y facturación) en los meses 1, 3, 9 y 12 (Enero, Marzo, Septiembe y Diciembre). El mes 7 (Junio) es el menos productivo, lo que sugiere ajustar estrategias o presupuestos según estas tendencias.
# CONCLUSIONES
#
# 1.Distribución
#
# La mayoría de las campañas tienen una duración entre 200 y 500 días y una facturación entre 0.2 y 0.8 millones de euros.
# Hay una alta concentración de campañas (colores más claros, hasta 7 campañas) en el rango de 300-400 días y facturaciones de 0.4-0.6 millones de euros.
#
# 2.Relación duración-facturación
#
# No hay una correlación fuerte: campañas de duración similar (e.g., 300-400 días) pueden tener facturaciones muy diferentes (0.2 a 0.8 millones).
# Las campañas más largas (600-700 días) tienden a tener facturaciones más bajas (0.2-0.4 millones).
#
# 3.Concentración
#
# La mayor densidad de campañas ocurre en duraciones medias (300-400 días) con facturaciones moderadas, indicando que este rango podría ser el más común o efectivo.
#
# CONCLUSIONES GENERALES
#
# Las campañas con duraciones de 300-400 días tienden a ser las más frecuentes y generan facturaciones moderadas (0.4-0.6 millones). Sin embargo, alargar las campañas más allá de 500 días no parece aumentar significativamente la facturación, sugiriendo que duraciones optimizadas entre 300-400 días podrían ser ideales.
#
#
# Referral es el canal con mayor ROI promedio, seguido de paid y promotion.
# Organic tiene el ROI promedio más bajo, aunque la diferencia entre canales no es muy grande.
#
# CONCLUSIONES GENERALES
#
# Las empresas utilizan de forma equilibrada los diferentes canales de marketing, sin depender excesivamente de uno solo.
# El canal referral es el más eficiente en términos de retorno de inversión (ROI), por lo que podría ser interesante potenciarlo.
# No hay grandes diferencias en inversión y facturación entre canales, pero sí ligeras diferencias en eficiencia (ROI).
# CONCLUSIONES
#
# 1.Ingresos totales por tipo de campaña
#
# Las campañas de tipo email son las que más ingresos generan, seguidas por webinar, social media y podcast.
# La diferencia entre los principales tipos es relevante, pero todos aportan ingresos significativos.
#
# La combinación de bajo coste en las campañas por email, junto con la alta segmentación y la facilidad de medición puede ser la causa de que el email marketing sea muy eficiente para generar ingresos.
#
# 2.Distribución de la duración por tipo de campaña
#
# No se observa una influencia clara y directa de la duración de la campaña en los ingresos. Las campañas de los principales tipos (email, podcast, webinar, social media) presentan duraciones similares y, aun así, generan ingresos elevados. Además, la dispersión de los ingresos dentro de cada tipo de campaña es amplia, independientemente de la duración.
#
# CONCLUSIONES GENERALES
# Las campañas de email, webinar, social media y podcast son las más rentables y tienen duraciones similares. Se recomienda mantener una estrategia diversificada entre estos tipos y revisar la utilidad de campañas menos frecuentes o con baja aportación.
# CONCLUSIONES
#
# La mayoría de las campañas tienen un ROI entre 0 y 1, con una distribución bastante uniforme, lo que indica que no hay un grupo dominante de campañas extremadamente exitosas o fallidas.
#
# La media del ROI es aproximadamente 0.54, lo que significa que, en promedio, las campañas generan un retorno positivo, aunque no muy elevado.
#
# No se observan valores extremos ni asimetrías marcadas, lo que sugiere que la rentabilidad de las campañas es relativamente estable.
#
# En resumen, las campañas muestran un rendimiento variable, con un ROI mediano de 0.54, pero con oportunidades de mejora, ya que algunas alcanzan retornos mucho más altos.
#
# CONCLUSIONES GENERALES
#
# 1.Analizar campañas de alto rendimiento
#
# Identifica las campañas con ROI superior a 0.6 para entender qué factores (estrategia, canal, público objetivo) las hicieron exitosas y repite esos elementos en futuras campañas.
#
# 2.Optimizar campañas de bajo rendimiento
#
# Revisa las campañas con ROI por debajo de 0.2 para identificar problemas (como segmentación incorrecta o bajo presupuesto) y ajusta las estrategias en consecuencia.
#
# 3.Establecer un objetivo realista
#
# Apuntar a superar la mediana de 0.54 como meta inicial, ajustándola según los resultados obtenidos.
# CONCLUSIONES
#
# Mejor desempeño: Las campañas de "Email" en "Organic" y "Referral" destacan con los ROIs más altos (hasta 0.8). "Social Media" también funciona bien en estos canales.
#
# Estabilidad: "Paid" ofrece un ROI más predecible, con "Email" y "Webinar" como opciones sólidas.
#
# Menor rendimiento: "Podcast" tiende a tener un ROI más bajo y consistente en todos los canales.
#
# Variabilidad: "Organic" muestra la mayor dispersión, indicando oportunidades y riesgos dependiendo de la ejecución.
#
# En resumen, las campañas de "Email" en "Organic" y "Referral" son las más prometedoras, mientras que "Podcast" podría necesitar ajustes. "Paid" ofrece estabilidad, pero con menos picos altos.
# CONCLUSIONES
#
# 1.Tasa de conversión por tipo de cliente:
#
# B2B: La tasa de conversión promedio es de 0.551, la más alta de los tres grupos.
# B2C: La tasa es de 0.537, ligeramente inferior a B2B pero aún competitiva.
# Sin datos: La tasa de conversión es de 0.475, notablemente más baja que B2B y B2C.
#
# 2.Comparación:
# Los clientes B2B tienen una tasa de conversión un 2.6% más alta que los B2C (0.551 vs. 0.537), lo que sugiere que las estrategias dirigidas a empresas funcionan mejor.
# El grupo "sin datos" tiene una tasa de conversión un 11.5% menor que B2B y un 9.1% menor que B2C, indicando que la falta de información sobre el tipo de cliente puede estar afectando negativamente las conversiones.
#
# CONCLUSIONES GENERALES
#
# La diferencia entre B2B y B2C es pequeña, lo que indica que las estrategias para ambos tipos de clientes son relativamente efectivas, pero hay un margen de mejora en B2C.
# CONCLUSIONES
#
# 1.Beneficio Neto
#
# Todos los canales tienen beneficios netos muy cercanos, oscilando entre 0.96M€ y 0.99M€.
# "Organic" y "Paid" alcanzan el máximo beneficio de 0.99M€ en varias instancias.
# "Referral" y "Promotion" muestran beneficios ligeramente menores (0.977M€ y 0.96M€, respectivamente).
#
# 2.Duración
#
# Las duraciones varían ampliamente, desde 261 días ("Organic") hasta 534 días ("Organic" y "Referral").
# "Organic" tiene la mayor variabilidad en duración (261 a 534 días).
# "Promotion" tiene la duración más corta (334 días), mientras que "Referral" incluye la duración más larga (534 días).
#
# 3.Relación Beneficio-Duración
#
# No hay una correlación clara entre duración y beneficio neto. Por ejemplo, "Organic" con 306 días y 534 días ambos alcanzan 0.99M€, mientras que "Promotion" con 334 días solo llega a 0.96M€.
# Canales con duraciones más cortas (e.g., 261 días en "Organic") pueden lograr beneficios comparables a los de mayor duración (e.g., 534 días).
#
# CONCLUSIONES GENERALES
#
# Los canales "Organic" y "Paid" son los más consistentes en generar el beneficio neto más alto (0.99M€), independientemente de la duración.
# "Promotion" ofrece el menor beneficio (0.96M€) a pesar de una duración moderada, sugiriendo menos eficiencia.
# La duración de las campañas no parece ser un factor determinante en el beneficio neto, lo que indica que la optimización del canal y la estrategia podrían ser más críticas que el tiempo invertido.
